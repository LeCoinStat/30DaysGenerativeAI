# %% [markdown]
# # Importer les données

# %%
# Importer les bibliothèques nécessaires
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Charger le jeu de données à partir d'un fichier CSV
df = pd.read_csv('Churn.csv')


df
# Out:
#      Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0     7590-VHVEA  Female               0     Yes         No       1
# 1     7590-VHVEG  Female               0     Yes         No       1
# 2     5575-GNVDE    Male               0      No         No      34
# 3     3668-QPYBK    Male               0      No         No       2
# 4     7795-CFOCW    Male               0      No         No      45
# ...          ...     ...             ...     ...        ...     ...
# 7039  6840-RESVB    Male               0     Yes        Yes      24
# 7040  2234-XADUH  Female               0     Yes        Yes      72
# 7041  4801-JZAZL  Female               0     Yes        Yes      11
# 7042  8361-LTMKD    Male               1     Yes         No       4
# 7043  3186-AJIEK    Male               0      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0               No  No phone service              DSL              No  ...
# 1               No  No phone service              DSL              No  ...
# 2              Yes                No              DSL             Yes  ...
# 3              Yes                No              DSL             Yes  ...
# 4               No  No phone service              DSL             Yes  ...
# ...            ...               ...              ...             ...  ...
# 7039           Yes               Yes              DSL             Yes  ...
# 7040           Yes               Yes      Fiber optic              No  ...
# 7041            No  No phone service              DSL             Yes  ...
# 7042           Yes               Yes      Fiber optic              No  ...
# 7043           Yes                No      Fiber optic             Yes  ...
#
#      Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                   No           No           No               No
# 1                   No           No           No               No
# 2                  Yes           No           No               No
# 3                   No           No           No               No
# 4                  Yes          Yes           No               No
# ...                ...          ...          ...              ...
# 7039               Yes          Yes          Yes              Yes
# 7040               Yes           No          Yes              Yes
# 7041                No           No           No               No
# 7042                No           No           No               No
# 7043               Yes          Yes          Yes              Yes
#
#             Contract Paperless Billing             Payment Method  \
# 0     Month-to-month               Yes           Electronic check
# 1     Month-to-month               Yes           Electronic check
# 2           One year                No               Mailed check
# 3     Month-to-month               Yes               Mailed check
# 4           One year                No  Bank transfer (automatic)
# ...              ...               ...                        ...
# 7039        One year               Yes               Mailed check
# 7040        One year               Yes    Credit card (automatic)
# 7041  Month-to-month               Yes           Electronic check
# 7042  Month-to-month               Yes               Mailed check
# 7043        Two year               Yes  Bank transfer (automatic)
#
#      Monthly Charges  Total Charges Churn
# 0              29.85          29.85    No
# 1              29.85          29.85    No
# 2              56.95         1889.5    No
# 3              53.85         108.15   Yes
# 4              42.30        1840.75    No
# ...              ...            ...   ...
# 7039           84.80         1990.5    No
# 7040          103.20         7362.9    No
# 7041           29.60         346.45    No
# 7042           74.40          306.6   Yes
# 7043          105.65         6844.5    No
#
# [7044 rows x 21 columns]

# %%
# Séparer les caractéristiques (X) et la variable cible (y)
X = pd.get_dummies(df.drop(['Churn', 'Customer ID'], axis=1))
y = df['Churn'].apply(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# # Description des données

# %%
df.describe(include="all")
# Out:
#        Customer ID Gender  Senior Citizen Partner Dependents       tenure  \
# count         7044   7044     7044.000000    7044       7044  7044.000000
# unique        7044      2             NaN       2          2          NaN
# top     7590-VHVEA   Male             NaN      No         No          NaN
# freq             1   3555             NaN    3641       4934          NaN
# mean           NaN    NaN        0.162124     NaN        NaN    32.366695
# std            NaN    NaN        0.368590     NaN        NaN    24.560582
# min            NaN    NaN        0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN        0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN        0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN        0.000000     NaN        NaN    55.000000
# max            NaN    NaN        1.000000     NaN        NaN    72.000000
#
#        Phone Service Multiple Lines Internet Service Online Security  ...  \
# count           7044           7044             7044            7044  ...
# unique             2              3                3               3  ...
# top              Yes             No      Fiber optic              No  ...
# freq            6361           3390             3096            3499  ...
# mean             NaN            NaN              NaN             NaN  ...
# std              NaN            NaN              NaN             NaN  ...
# min              NaN            NaN              NaN             NaN  ...
# 25%              NaN            NaN              NaN             NaN  ...
# 50%              NaN            NaN              NaN             NaN  ...
# 75%              NaN            NaN              NaN             NaN  ...
# max              NaN            NaN              NaN             NaN  ...
#
#        Device Protection Tech Support Streaming TV Streaming Movies  \
# count               7044         7044         7044             7044
# unique                 3            3            3                3
# top                   No           No           No               No
# freq                3096         3474         2811             2786
# mean                 NaN          NaN          NaN              NaN
# std                  NaN          NaN          NaN              NaN
# min                  NaN          NaN          NaN              NaN
# 25%                  NaN          NaN          NaN              NaN
# 50%                  NaN          NaN          NaN              NaN
# 75%                  NaN          NaN          NaN              NaN
# max                  NaN          NaN          NaN              NaN
#
#               Contract Paperless Billing    Payment Method Monthly Charges  \
# count             7044              7044              7044     7044.000000
# unique               3                 2                 4             NaN
# top     Month-to-month               Yes  Electronic check             NaN
# freq              3876              4172              2366             NaN
# mean               NaN               NaN               NaN       64.756736
# std                NaN               NaN               NaN       30.090786
# min                NaN               NaN               NaN       18.250000
# 25%                NaN               NaN               NaN       35.500000
# 50%                NaN               NaN               NaN       70.350000
# 75%                NaN               NaN               NaN       89.850000
# max                NaN               NaN               NaN      118.750000
#
#         Total Charges Churn
# count            7044  7044
# unique           6531     2
# top              20.2    No
# freq               11  5175
# mean              NaN   NaN
# std               NaN   NaN
# min               NaN   NaN
# 25%               NaN   NaN
# 50%               NaN   NaN
# 75%               NaN   NaN
# max               NaN   NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# #  Diviser les données en ensembles d'entraînement et de test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# Afficher les premières lignes de la variable cible d'entraînement
y_train.head()
# Out:
# 1576    1
# 1251    0
# 1395    0
# 1287    0
# 3826    0
# Name: Churn, dtype: int64

# %% [markdown]
# # Deeplearning avec tensorflow

# %% [markdown]
# ## Importer les dépendances

# %%
# Importer les bibliothèques nécessaires pour construire le modèle et évaluer les performances
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Construire et compiler le modèle

# %%
# Créer un modèle séquentiel
model = Sequential()

# Ajouter une couche Dense avec 32 neurones et une activation ReLU(Rectified Linear Unit) 
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
# Ajouter une autre couche Dense avec 64 neurones et une activation ReLU
model.add(Dense(units=64, activation='relu'))
# Ajouter la couche de sortie Dense avec 1 neurone et une activation sigmoïde
model.add(Dense(units=1, activation='sigmoid'))




# Compiler le modèle en spécifiant la fonction de perte et l'optimiseur
# Epoch 183/200
# 177/177 [==============================] - 0s 723us/step - loss: 0.4158 - accuracy: 0.8027
# Epoch 184/200
# 177/177 [==============================] - 0s 696us/step - loss: 0.4173 - accuracy: 0.7993
# Epoch 185/200
# 177/177 [==============================] - 0s 693us/step - loss: 0.4175 - accuracy: 0.8027
# Epoch 186/200
# 177/177 [==============================] - 0s 693us/step - loss: 0.4157 - accuracy: 0.8025
# Epoch 187/200
# 177/177 [==============================] - 0s 720us/step - loss: 0.4165 - accuracy: 0.8039
# Epoch 188/200
# 177/177 [==============================] - 0s 710us/step - loss: 0.4168 - accuracy: 0.8051
# Epoch 189/200
# 177/177 [==============================] - 0s 718us/step - loss: 0.4176 - accuracy: 0.7961
# Epoch 190/200
# 177/177 [==============================] - 0s 720us/step - loss: 0.4157 - accuracy: 0.7980
# Epoch 191/200
# 177/177 [==============================] - 0s 710us/step - loss: 0.4171 - accuracy: 0.7973
# Epoch 192/200
# 177/177 [==============================] - 0s 705us/step - loss: 0.4167 - accuracy: 0.8007
# Epoch 193/200
# 177/177 [==============================] - 0s 740us/step - loss: 0.4191 - accuracy: 0.7998
# Epoch 194/200
# 177/177 [==============================] - 0s 779us/step - loss: 0.4161 - accuracy: 0.7982
# Epoch 195/200
# 177/177 [==============================] - 0s 763us/step - loss: 0.4164 - accuracy: 0.8035
# Epoch 196/200
# 177/177 [==============================] - 0s 709us/step - loss: 0.4161 - accuracy: 0.8012
# Epoch 197/200
# 177/177 [==============================] - 0s 710us/step - loss: 0.4149 - accuracy: 0.8030
# Epoch 198/200
# 177/177 [==============================] - 0s 691us/step - loss: 0.4172 - accuracy: 0.8027
# Epoch 199/200
# 177/177 [==============================] - 0s 715us/step - loss: 0.4161 - accuracy: 0.8007
# Epoch 200/200
# 177/177 [==============================] - 0s 708us/step - loss: 0.4159 - accuracy: 0.8066

# %%
# Faire des prédictions sur les données de test
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]

# Calculer la précision du modèle
accuracy = accuracy_score(y_test, y_hat)

accuracy
# Out:
# 45/45 [==============================] - 0s 545us/step
# 0.7686302342086586

# %% [markdown]
# # DeepLearning avec Pytorch

# %%
# Importer les bibliothèques nécessaires
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## Construire et compiler le modèle

# %%
# Créer une classe de modèle PyTorch personnalisée
class Net(nn.Module):
    def __init__(self):
        """
        Initialise un modèle de réseau de neurones artificiels.

        Ce modèle a trois couches fully connected (entièrement connectées).
        
        Couches :
        - Couche 1 : 32 neurones avec une activation ReLU
        - Couche 2 : 64 neurones avec une activation ReLU
        - Couche 3 : 1 neurone avec une activation sigmoïde (pour la sortie binaire)
        """
        super(Net, self).__init__()
        self.fc1 = nn.Linear(len(X_train.columns), 32)
        self.fc2 = nn.Linear(32, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        """
        Effectue une propagation avant (forward pass) à travers le modèle.

        Args:
            x (torch.Tensor): Les données d'entrée.

        Returns:
            torch.Tensor: Les prédictions du modèle.
        """
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x

# %%
# Créer une instance du modèle
model = Net()

# Définir la fonction de perte et l'optimiseur
criterion = nn.BCELoss()  # Binary Cross-Entropy Loss
optimizer = optim.SGD(model.parameters(), lr=0.01)  # Stochastic Gradient Descent avec un taux d'apprentissage de 0.01

# %% [markdown]
# ## Entraîner, prédire et évaluer

# %%
def train(model, X_train, y_train, criterion, optimizer, epochs=200, batch_size=32):
    """
    Entraîne le modèle.

    Args:
        model (torch.nn.Module): Le modèle à entraîner.
        X_train (pd.DataFrame): Les données d'entraînement.
        y_train (pd.Series): Les étiquettes d'entraînement.
        criterion (torch.nn.Module): La fonction de perte.
        optimizer (torch.optim.Optimizer): L'optimiseur.
        epochs (int): Le nombre d'époques d'entraînement.
        batch_size (int): La taille du lot (mini-batch).

    Returns:
        None
    """
    for epoch in range(epochs):
        total_loss = 0.0
        for i in range(0, len(X_train), batch_size):
            inputs = torch.tensor(X_train[i:i+batch_size].values, dtype=torch.float32)
            labels = torch.tensor(y_train[i:i+batch_size].values, dtype=torch.float32).view(-1, 1)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            # Ajout pour afficher la perte à chaque étape
            total_loss += loss.item()

        # Afficher la perte et l'époque
        print(f'Époque [{epoch+1}/{epochs}], Perte: {total_loss}')

    # Message lorsque l'entraînement est terminé
    print('Entraînement terminé.')

# Exemple d'utilisation de la fonction train
# train(mon_modele, X_train, y_train, ma_fonction_de_perte, mon_optimiseur, epochs=200, batch_size=32)

# %%
# Entraîner le modèle
train(model, X_train, y_train, criterion, optimizer, epochs=200, batch_size=32)
# Out:
# Époque [1/200], Perte: 75.28906060755253
# Époque [2/200], Perte: 75.2606239169836
# Époque [3/200], Perte: 75.23119007050991
# Époque [4/200], Perte: 75.2021361887455
# Époque [5/200], Perte: 75.18140564858913
# Époque [6/200], Perte: 75.11924780905247
# Époque [7/200], Perte: 75.14686433970928
# Époque [8/200], Perte: 75.1219190210104
# Époque [9/200], Perte: 75.09348464012146
# Époque [10/200], Perte: 75.0481893569231
# Époque [11/200], Perte: 75.02841195464134
# Époque [12/200], Perte: 75.0238744020462
# Époque [13/200], Perte: 74.94838812947273
# Époque [14/200], Perte: 74.97229816019535
# Époque [15/200], Perte: 74.93185412883759
# Époque [16/200], Perte: 74.90590378642082
# Époque [17/200], Perte: 74.87911635637283
# Époque [18/200], Perte: 74.858063980937
# Époque [19/200], Perte: 74.83558249473572
# Époque [20/200], Perte: 74.8403559178114
# Époque [21/200], Perte: 74.80575221776962
# Époque [22/200], Perte: 74.80898253619671
# Époque [23/200], Perte: 74.75115443766117
# Époque [24/200], Perte: 74.71364395320415
# Époque [25/200], Perte: 74.69462265074253

# %%
# Fonction de prédiction
def predict(model, X_test):
    """
    Effectue des prédictions à l'aide du modèle.

    Args:
        model (torch.nn.Module): Le modèle entraîné.
        X_test (pd.DataFrame): Les données de test.

    Returns:
        torch.Tensor: Les prédictions du modèle.
    """
    with torch.no_grad():
        inputs = torch.tensor(X_test.values, dtype=torch.float32)
        outputs = model(inputs)
        predictions = (outputs >= 0.5).float()
    return predictions

# Faire des prédictions sur les données de test
y_hat = predict(model, X_test)

# %%
# Calculer la précision du modèle
accuracy = (y_hat == torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)).float().mean()
accuracy
